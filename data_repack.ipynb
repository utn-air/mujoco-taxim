# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
# with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/bg_set.npz", "rb") as f:
#     digit_bg = np.load(f, allow_pickle=True)
#     bgs = digit_bg["f0"]

# fixed = []
# print(len(bgs))
fixed = []
bgs = os.listdir("./blanks")
bgs = sorted(bgs)
print(bgs)
for i, bg in enumerate(bgs):
    bg = Image.open(os.path.join("./blanks", bg))
    # bg = Image.fromarray(bg)
    bg =  bg.transpose(Image.FLIP_TOP_BOTTOM)
    bg = bg.rotate(90, expand=True)
    bg = bg.resize((640, 480))
    bg = np.array(bg)
    fixed.append(bg)
print(len(fixed))
np.savez_compressed("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/bg_set.npz", f0=fixed)
# Out:
# ['object_001_blank.png', 'object_002_blank.png', 'object_003_blank.png', 'object_004_blank.png', 'object_005_blank.png', 'object_006_blank.png', 'object_007_blank.png', 'object_008_blank.png', 'object_009_blank.png', 'object_010_blank.png', 'object_011_blank.png', 'object_012_blank.png', 'object_013_blank.png', 'object_014_blank.png', 'object_015_blank.png', 'object_016_blank.png', 'object_017_blank.png', 'object_018_blank.png', 'object_019_blank.png', 'object_020_blank.png', 'object_021_blank.png', 'object_022_blank.png', 'object_023_blank.png', 'object_024_blank.png', 'object_025_blank.png', 'object_026_blank.png', 'object_027_blank.png', 'object_028_blank.png', 'object_029_blank.png', 'object_030_blank.png', 'object_031_blank.png', 'object_032_blank.png', 'object_033_blank.png', 'object_034_blank.png', 'object_035_blank.png', 'object_036_blank.png', 'object_037_blank.png', 'object_038_blank.png', 'object_039_blank.png', 'object_040_blank.png', 'object_041_blank.png', 'object_042_blank.png', 'object_043_blank.png', 'object_044_blank.png', 'object_045_blank.png', 'object_046_blank.png', 'object_047_blank.png', 'object_048_blank.png', 'object_049_blank.png', 'object_050_blank.png', 'object_051_blank.png', 'object_052_blank.png', 'object_053_blank.png', 'object_054_blank.png', 'object_055_blank.png', 'object_056_blank.png', 'object_057_blank.png', 'object_058_blank.png', 'object_059_blank.png', 'object_060_blank.png', 'object_061_blank.png', 'object_062_blank.png', 'object_063_blank.png', 'object_064_blank.png', 'object_065_blank.png', 'object_066_blank.png', 'object_067_blank.png', 'object_068_blank.png', 'object_069_blank.png', 'object_070_blank.png', 'object_071_blank.png', 'object_072_blank.png', 'object_073_blank.png', 'object_074_blank.png', 'object_075_blank.png', 'object_076_blank.png', 'object_077_blank.png', 'object_078_blank.png', 'object_079_blank.png', 'object_080_blank.png', 'object_081_blank.png', 'object_082_blank.png', 'object_083_blank.png', 'object_084_blank.png', 'object_085_blank.png', 'object_086_blank.png', 'object_087_blank.png', 'object_088_blank.png', 'object_089_blank.png', 'object_090_blank.png', 'object_091_blank.png', 'object_092_blank.png', 'object_093_blank.png', 'object_094_blank.png', 'object_095_blank.png', 'object_096_blank.png', 'object_097_blank.png', 'object_098_blank.png', 'object_099_blank.png', 'object_100_blank.png']
# 100

# %%
import numpy as np

with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/bg_set.npz", "rb") as f:
    digit_bg = np.load(f, allow_pickle=True)
    bgs_fixed = digit_bg["f0"]
len(bgs_fixed)

bgs_resized = []
for bg in bgs_fixed:
    print(bg.shape)
# np.savez_compressed("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/bg_set.npz", f0=bgs_resized)
# Out:
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)

# %%
with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/bg_set.npz", "rb") as f:
    digit_bg = np.load(f, allow_pickle=True)
    bgs = digit_bg["f0"]
with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/bg_set_fixed.npz", "rb") as f:
    digit_bg = np.load(f, allow_pickle=True)
    bgs_fixed = digit_bg["f0"]

for i, (bg, bg_fixed) in enumerate(zip(bgs, bgs_fixed)):
    print(f"Background {i}: {bg.shape}, Fixed: {bg_fixed.shape}")
    plt.subplot(1, 2, 1)
    plt.title("Original")
    plt.imshow(bg)
    plt.subplot(1, 2, 2)
    plt.title("Fixed")
    plt.imshow(bg_fixed)
    plt.show()
    break
# Out:
# Background 0: (480, 640, 3), Fixed: (480, 640, 3)

# %%
with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/digit/bg_set.npz", "rb") as f:
    digit_bg = np.load(f, allow_pickle=True)
    bgs = digit_bg["f0"]
for i, bg in enumerate(bgs):
    print(f"Background {i}: {bg.shape}")
    plt.imshow(bg)
    plt.show()
# Out:
# Background 0: (480, 640, 3)
# Background 1: (480, 640, 3)
# Background 2: (480, 640, 3)
# Background 3: (480, 640, 3)
# Background 4: (480, 640, 3)
# Background 5: (480, 640, 3)
# Background 6: (480, 640, 3)
# Background 7: (480, 640, 3)
# Background 8: (480, 640, 3)
# Background 9: (480, 640, 3)
# Background 10: (480, 640, 3)

# %%
import pickle
import numpy as np
with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/digit/bg_set.npz", "rb") as f:
    digit_bg = np.load(f, allow_pickle=True)
with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/digit/polycalib.npz", "rb") as f:
    digit_polycalib = np.load(f, allow_pickle=True)
with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/dataPack.npz", "rb") as f:
    gs_dp = np.load(f, allow_pickle=True)
    gs_bg = gs_dp['f0'].copy()
with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/polycalib.npz", "rb") as f:
    gs_polycalib = np.load(f, allow_pickle=True)

# %%
gs_bg.shape
import matplotlib.pyplot as plt
plt.imshow (gs_bg)
np.savez_compressed("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/bg_set.npz", f0=gs_bg)
# gs_dp.keys()

# %%
with open("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/digit/bg_set.npz", "rb") as f:
    digit_bg = np.load(f, allow_pickle=True)
    print(digit_bg['f0'].shape)

# %%
blanks = []
from PIL import Image
for i in range(0, 100):
    with Image.open(f"/home/sbien/Documents/Development/Vision2Touch/Taxim/ofr_bgs/object_{i+1:03d}_blank_image.png") as img:
        img = img.resize((480, 640))
        img = img.rotate(-90, expand=True)

        blanks.append(np.array(img))
blanks = np.array(blanks)
plt.imshow(blanks[0])

# %%
blanks.shape
np.savez_compressed("/home/sbien/Documents/Development/Vision2Touch/Taxim/src/TaximSensor/calibs/gelsight_r1.5/bg_set.npz", f0=blanks)
